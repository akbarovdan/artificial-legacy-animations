# %%
# D0L system
list = ['b']
for i in range(0,10):
    if 'a' in list:
        idx = list.index('a')
        list.insert(idx + 1, 'b')
    list = ['a' if x == 'b' else x for x in list]

    print(f'{i}: {list}')
# Out:
# 0 b
# 0 a
# 0 a
# 0 a
# 0 a
# 0 a
# 0 a
# 0 a
# 0 a
# 0 a
